# %% [markdown]
# Using a pre-trained satellite image classifier from `Kaggle`, I will analyze the my satellite data using a `fire` and `nofire` set of image(s)

# %% [markdown]
# `Kaggle` sources, choose one or many:
#
# 1. [Satellite Image classification by aravindanr](https://www.kaggle.com/code/aravindanr22052001/satellite-image-classification)
#
# 1. [Intel Image Classification by Puneet Bansal](https://www.kaggle.com/datasets/puneet6060/intel-image-classification)
#
# 1. [Image Classification using CNN (94%+ Accuracy) by ask9](https://www.kaggle.com/code/arbazkhan971/image-classification-using-cnn-94-accuracy)
#
# 1. [Satellite Image Classification by Mahmoud Reda](https://www.kaggle.com/datasets/mahmoudreda55/satellite-image-classification)
#
# 1. [🛰️Satellite Image Classification | CNN by Sujith K Mandala](https://www.kaggle.com/code/sujithmandala/satellite-image-classification-cnn)

# %% [markdown]
# I will start with <mark>number 1</mark> because it has the highest accuracy.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import cv2

# %%
# from kaggle 1

# import cv2
# import numpy as np
# import pandas as pd 
# import matplotlib.pyplot as plt 

# import tensorflow as tf 
# from keras.models import Sequential 
# from tensorflow.keras.layers import Dense,Flatten,Conv2D,MaxPooling2D, GlobalAveragePooling2D
# from keras.preprocessing.image import ImageDataGenerator, load_img 

# from IPython import display 
# display.set_matplotlib_formats('svg')

# %% [markdown]
# ### Tutorial for [visualizing tiff files](https://www.geeksforgeeks.org/visualizing-tiff-file-using-matplotlib-and-gdal-using-python/)

# %%
from osgeo import gdal
import matplotlib.pyplot as plt

fire=r'/Users/sra/Desktop/Data_Science_2023/_capstone/00_capstone_data/orthoimagery/2018/ortho_2018_sm_fire.tif'
nofire=r'/Users/sra/Desktop/Data_Science_2023/_capstone/00_capstone_data/orthoimagery/2018/ortho_2018_sm_nofire.tif'
  
dataset_fire = gdal.Open(fire)

# %%
# print the number of bands

print(dataset_fire.RasterCount)

# %%
# since there are 4 bands
# we store in 4 different variables

band1_red = dataset.GetRasterBand(1) # Red channel
band2_gre = dataset.GetRasterBand(2) # Green channel
band3_blu = dataset.GetRasterBand(3) # Blue channel

# %%
# read bands as numpy arrays

b1 = band1_red.ReadAsArray()
b2 = band2_gre.ReadAsArray()
b3 = band3_blu.ReadAsArray()

# %%
# warning: this won't work because the files are too large
# # plot the arrays

# img = np.dstack((b1, b2, b3))
# f = plt.figure()
# plt.imshow(img)
# plt.savefig('fire.png')
# plt.show()

# %%
# https://gis.stackexchange.com/questions/14712/splitting-raster-into-smaller-chunks-using-gdal

fire=r'/Users/sra/Desktop/Data_Science_2023/_capstone/00_capstone_data/orthoimagery/2018/ortho_2018_sm_fire.tif'
nofire=r'/Users/sra/Desktop/Data_Science_2023/_capstone/00_capstone_data/orthoimagery/2018/ortho_2018_sm_nofire.tif'

from osgeo import gdal
from gdalconst import *

width = 512
height = 512
tilesize = 64

for i in range(0, width, tilesize):
    for j in range(0, height, tilesize):
        gdaltranString = f"gdal_translate -of {fire} -srcwin "+str(i)+", "+str(j)+", "+str(tilesize)+", " \
            +str(tilesize)+" utm.tif utm_"+str(i)+"_"+str(j)+".tif"
        os.system(gdaltranString)

# %%
pd.set_option('display.max_rows', 10)

# %%
pd.set_option('display.max_columns', None)

# %%
df=pd.read_csv('/Users/sra/Desktop/Data_Science_2023/_capstone/02_capstone_presentations/presentation_2023-03-24/2023_Wildland_Fire_Incident_Locations_to_Date.csv')

df
# Out:
#                X          Y  OBJECTID  SourceOID ABCDMisc ADSPermissionState  \
# 0    -118.106402  33.891095    292628   23872143      NaN            DEFAULT
# 1    -120.437306  36.821662    292630   23872145      NaN            DEFAULT
# 2    -117.890182  34.121065    292661   23872184      NaN            DEFAULT
# 3    -116.227787  33.719351    292664   23872185      NaN            DEFAULT
# 4    -116.509916  33.962375    292672   23872187      NaN            DEFAULT
# ...          ...        ...       ...        ...      ...                ...
# 3870 -103.067809  36.619946    300103   28020430      NaN            DEFAULT
# 3871 -103.036209  36.503966    300104   28020431      NaN            DEFAULT
# 3872 -108.543977  44.784403    300105   28020432      NaN            DEFAULT
# 3873  -81.071403  27.527615    300106   28020433      NaN            DEFAULT
# 3874  -83.197204  37.994507    300107   28020434      NaN            DEFAULT
#
#          ContainmentDateTime         ControlDateTime CreatedBySystem  \
# 0                        NaN                     NaN         lacocad
# 1     2023/01/01 06:20:56+00  2023/01/01 06:21:02+00           cfcad
# 2                        NaN                     NaN         lacocad
# 3                        NaN                     NaN           cfcad
# 4                        NaN                     NaN           cfcad
# ...                      ...                     ...             ...
# 3870                     NaN                     NaN         wildcad
# 3871                     NaN                     NaN         wildcad
# 3872  2023/03/22 13:53:57+00                     NaN             ers
# 3873                     NaN                     NaN         wildcad
# 3874  2023/03/22 00:07:18+00  2023/03/22 00:24:23+00      firesponse
#
#       IncidentSize  DiscoveryAcres DispatchCenterID  EstimatedCostToDate  \
# 0              NaN            0.01           CALACC                  NaN
# 1             0.01            0.01           CAFKCC                  NaN
# 2              NaN            0.01           CALACC                  NaN
# 3              NaN            0.01           CARRCC                  NaN
# 4              NaN            0.01           CARRCC                  NaN
# ...            ...             ...              ...                  ...
# 3870          1.00            1.00            NMABC                  NaN
# 3871          1.00            1.00            NMABC                  NaN
# 3872         51.00             NaN            WYCDC                  NaN
# 3873          1.00            1.00            FLFIC                  NaN
# 3874          1.00            1.00            KYKIC                  NaN
#
#       FinalAcres  FinalFireReportApprovedByTitle  \
# 0            NaN                             NaN
# 1            NaN                             NaN
# 2            NaN                             NaN
# 3            NaN                             NaN
# 4            NaN                             NaN
# ...          ...                             ...
# 3870         NaN                             NaN
# 3871         NaN                             NaN
# 3872        51.0                             NaN
# 3873         NaN                             NaN
# 3874         NaN                             NaN
#
#       FinalFireReportApprovedByUnit  FinalFireReportApprovedDate  \
# 0                               NaN                          NaN
# 1                               NaN                          NaN
# 2                               NaN                          NaN
# 3                               NaN                          NaN
# 4                               NaN                          NaN
# ...                             ...                          ...
# 3870                            NaN                          NaN
# 3871                            NaN                          NaN
# 3872                            NaN                          NaN
# 3873                            NaN                          NaN
# 3874                            NaN                          NaN
#
#      FireBehaviorGeneral FireBehaviorGeneral1 FireBehaviorGeneral2  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3                    NaN                  NaN                  NaN
# 4                    NaN                  NaN                  NaN
# ...                  ...                  ...                  ...
# 3870                 NaN                  NaN                  NaN
# 3871                 NaN                  NaN                  NaN
# 3872                 NaN                  NaN                  NaN
# 3873                 NaN                  NaN                  NaN
# 3874                 NaN                  NaN                  NaN
#
#      FireBehaviorGeneral3     FireCause                 FireCauseGeneral  \
# 0                     NaN  Undetermined                              NaN
# 1                     NaN  Undetermined                              NaN
# 2                     NaN  Undetermined                              NaN
# 3                     NaN  Undetermined                              NaN
# 4                     NaN  Undetermined                              NaN
# ...                   ...           ...                              ...
# 3870                  NaN  Undetermined                              NaN
# 3871                  NaN  Undetermined                              NaN
# 3872                  NaN         Human  Undetermined (remarks required)
# 3873                  NaN  Undetermined                              NaN
# 3874                  NaN         Human          Debris and open burning
#
#      FireCauseSpecific FireCode FireDepartmentID   FireDiscoveryDateTime  \
# 0                  NaN      NaN              NaN  2023/01/01 04:43:57+00
# 1                  NaN      NaN              NaN  2023/01/01 05:31:41+00
# 2                  NaN      NaN              NaN  2023/01/01 08:55:36+00
# 3                  NaN      NaN              NaN  2023/01/01 08:22:21+00
# 4                  NaN      NaN              NaN  2023/01/01 08:48:45+00
# ...                ...      ...              ...                     ...
# 3870               NaN      NaN              NaN  2023/03/22 13:33:51+00
# 3871               NaN      NaN              NaN  2023/03/22 13:36:12+00
# 3872               NaN      NaN            03521  2023/03/20 20:25:00+00
# 3873               NaN      NaN              NaN  2023/03/22 10:58:21+00
# 3874       Yard debris      NaN              NaN  2023/03/21 22:05:00+00
#
#      FireMgmtComplexity FireOutDateTime  FireStrategyConfinePercent  \
# 0                   NaN             NaN                         NaN
# 1                   NaN             NaN                         NaN
# 2                   NaN             NaN                         NaN
# 3                   NaN             NaN                         NaN
# 4                   NaN             NaN                         NaN
# ...                 ...             ...                         ...
# 3870                NaN             NaN                         NaN
# 3871                NaN             NaN                         NaN
# 3872                NaN             NaN                         NaN
# 3873                NaN             NaN                         NaN
# 3874    Type 5 Incident             NaN                         NaN
#
#       FireStrategyFullSuppPercent  FireStrategyMonitorPercent  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
# ...                           ...                         ...
# 3870                          NaN                         NaN
# 3871                          NaN                         NaN
# 3872                          NaN                         NaN
# 3873                          NaN                         NaN
# 3874                          NaN                         NaN
#
#       FireStrategyPointZonePercent FSJobCode  FSOverrideCode  GACC  \
# 0                              NaN       NaN             NaN  OSCC
# 1                              NaN       NaN             NaN  OSCC
# 2                              NaN       NaN             NaN  OSCC
# 3                              NaN       NaN             NaN  OSCC
# 4                              NaN       NaN             NaN  OSCC
# ...                            ...       ...             ...   ...
# 3870                           NaN       NaN             NaN  SWCC
# 3871                           NaN       NaN             NaN  SWCC
# 3872                           NaN       NaN             NaN  RMCC
# 3873                           NaN       NaN             NaN  SACC
# 3874                           NaN       NaN             NaN  SACC
#
#      ICS209ReportDateTime ICS209ReportForTimePeriodFrom  \
# 0                     NaN                           NaN
# 1                     NaN                           NaN
# 2                     NaN                           NaN
# 3                     NaN                           NaN
# 4                     NaN                           NaN
# ...                   ...                           ...
# 3870                  NaN                           NaN
# 3871                  NaN                           NaN
# 3872                  NaN                           NaN
# 3873                  NaN                           NaN
# 3874                  NaN                           NaN
#
#      ICS209ReportForTimePeriodTo ICS209ReportStatus  \
# 0                            NaN                NaN
# 1                            NaN                NaN
# 2                            NaN                NaN
# 3                            NaN                NaN
# 4                            NaN                NaN
# ...                          ...                ...
# 3870                         NaN                NaN
# 3871                         NaN                NaN
# 3872                         NaN                NaN
# 3873                         NaN                NaN
# 3874                         NaN                NaN
#
#      IncidentManagementOrganization                    IncidentName  \
# 0                               NaN                      LAC-447492
# 1                               NaN        W BULLARD AVE  FIREBAUGH
# 2                               NaN                      LAC-000069
# 3                               NaN                  BLISS AV  INDO
# 4                               NaN                    1ST ST  DHSP
# ...                             ...                             ...
# 3870                            NaN                          K74 Rx
# 3871                            NaN                          K44 Rx
# 3872                            NaN                              09
# 3873                            NaN      EHR Kissimmee Bend Rx 0322
# 3874                            NaN  Big Mandy Lane - Morgan County
#
#      IncidentShortDescription IncidentTypeCategory IncidentTypeKind  \
# 0                         NaN                   WF               FI
# 1                         NaN                   RX               FI
# 2                         NaN                   WF               FI
# 3                         NaN                   WF               FI
# 4                         NaN                   WF               FI
# ...                       ...                  ...              ...
# 3870                      NaN                   RX               FI
# 3871                      NaN                   RX               FI
# 3872                      NaN                   WF               FI
# 3873                      NaN                   RX               FI
# 3874                      NaN                   WF               FI
#
#       InitialLatitude  InitialLongitude  InitialResponseAcres  \
# 0           33.891090       -118.106390                   NaN
# 1           36.821657       -120.437293                   NaN
# 2           34.121060       -117.890170                   NaN
# 3           33.719346       -116.227775                   NaN
# 4           33.962370       -116.509904                   NaN
# ...               ...               ...                   ...
# 3870        36.619940       -103.067800                   NaN
# 3871        36.503960       -103.036200                   NaN
# 3872              NaN               NaN                   NaN
# 3873        27.527610        -81.071400                2023.0
# 3874        37.994500        -83.197200                   NaN
#
#      InitialResponseDateTime                                 IrwinID  \
# 0                        NaN  {CBF6F6BE-5A91-4963-B989-B53898DD0EEC}
# 1                        NaN  {8B3AE160-4F81-4A3D-850C-F931BADDD17C}
# 2                        NaN  {16443D72-F126-474A-B3B2-D21BFA7269CD}
# 3                        NaN  {D54F2E4C-AAE4-4EED-AEC9-63396F1FB6A4}
# 4                        NaN  {984EF428-A7DC-434C-A6DD-12345A31FEC1}
# ...                      ...                                     ...
# 3870                     NaN  {B09771D2-4945-4FB6-98B6-44CB32D8A324}
# 3871                     NaN  {C5A3E4D3-956A-469B-A06C-934B2EB0A385}
# 3872                     NaN  {E5EAC43B-7FF1-45ED-99EE-AB46A4380723}
# 3873                     NaN  {F593BD75-7647-4338-83E8-CCAD591BD204}
# 3874                     NaN  {66FB8350-DC25-4604-BDC8-7D8674C69760}
#
#       IsFireCauseInvestigated  IsFireCodeRequested  IsFSAssisted  \
# 0                         NaN                    0           NaN
# 1                         NaN                    0           0.0
# 2                         NaN                    0           NaN
# 3                         NaN                    0           0.0
# 4                         NaN                    0           0.0
# ...                       ...                  ...           ...
# 3870                      NaN                    0           1.0
# 3871                      NaN                    0           1.0
# 3872                      NaN                    0           NaN
# 3873                      NaN                    0           0.0
# 3874                      NaN                    0           NaN
#
#       IsMultiJurisdictional  IsReimbursable  IsTrespass  IsUnifiedCommand  \
# 0                       NaN             NaN         NaN               NaN
# 1                       0.0             0.0         0.0               NaN
# 2                       NaN             NaN         NaN               NaN
# 3                       0.0             0.0         0.0               NaN
# 4                       0.0             0.0         0.0               NaN
# ...                     ...             ...         ...               ...
# 3870                    0.0             0.0         0.0               NaN
# 3871                    0.0             0.0         0.0               NaN
# 3872                    NaN             NaN         NaN               NaN
# 3873                    0.0             0.0         0.0               NaN
# 3874                    NaN             NaN         NaN               0.0
#
#      LocalIncidentIdentifier ModifiedBySystem  PercentContained  \
# 0                     447492          lacocad               NaN
# 1                     022959            cfcad               NaN
# 2                     000069          lacocad               NaN
# 3                     000014            cfcad               NaN
# 4                     000035            cfcad               NaN
# ...                      ...              ...               ...
# 3870                  000048          wildcad               NaN
# 3871                  000049          wildcad               NaN
# 3872              0352100009              ers               NaN
# 3873                  001065          wildcad               NaN
# 3874               231750330       firesponse             100.0
#
#       PercentPerimeterToBeContained POOCity    POOCounty POODispatchCenterID  \
# 0                               NaN     NaN  Los Angeles              CALACC
# 1                               NaN     NaN       Fresno              CASICC
# 2                               NaN     NaN  Los Angeles              CALACC
# 3                               NaN     NaN    Riverside              CARRCC
# 4                               NaN     NaN    Riverside              CARRCC
# ...                             ...     ...          ...                 ...
# 3870                            NaN     NaN        Union               NMTDC
# 3871                            NaN     NaN        Union               NMTDC
# 3872                            NaN     NaN     Big Horn               WYCDC
# 3873                            NaN     NaN   Okeechobee               FLFIC
# 3874                            NaN     NaN       Morgan               KYKIC
#
#      POOFips POOJurisdictionalAgency POOJurisdictionalUnit  \
# 0      06037                     NaN                   NaN
# 1      06019                     NaN                   NaN
# 2      06037                     NaN                   NaN
# 3      06065                     NaN                   NaN
# 4      06065                     NaN                   NaN
# ...      ...                     ...                   ...
# 3870   35059                    USFS                 NMCIF
# 3871   35059                    USFS                 NMCIF
# 3872   56003                     NaN                   NaN
# 3873   12093                     FWS                 FLEHR
# 3874   21175                     DVF                 KYKYS
#
#       POOJurisdictionalUnitParentUnit POOLandownerCategory POOLandownerKind  \
# 0                                 NaN              Private          Private
# 1                                 NaN              Private          Private
# 2                                 NaN              Private          Private
# 3                                 NaN              Private          Private
# 4                                 NaN              Private          Private
# ...                               ...                  ...              ...
# 3870                              NaN                 USFS          Federal
# 3871                              NaN                 USFS          Federal
# 3872                              NaN              Private          Private
# 3873                              NaN                USFWS          Federal
# 3874                              NaN              Private          Private
#
#      POOLegalDescPrincipalMeridian POOLegalDescQtr  POOLegalDescQtrQtr  \
# 0                              NaN             NaN                 NaN
# 1                              NaN             NaN                 NaN
# 2                              NaN             NaN                 NaN
# 3                              NaN             NaN                 NaN
# 4                              NaN             NaN                 NaN
# ...                            ...             ...                 ...
# 3870                           NaN             NaN                 NaN
# 3871                           NaN             NaN                 NaN
# 3872                           NaN             NaN                 NaN
# 3873                           NaN             NaN                 NaN
# 3874                           NaN             NaN                 NaN
#
#      POOLegalDescRange  POOLegalDescSection POOLegalDescTownship  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
# ...                ...                  ...                  ...
# 3870               NaN                  NaN                  NaN
# 3871               NaN                  NaN                  NaN
# 3872               NaN                  NaN                  NaN
# 3873               NaN                  NaN                  NaN
# 3874               NaN                  NaN                  NaN
#
#      POOPredictiveServiceAreaID POOProtectingAgency POOProtectingUnit  \
# 0                          SC08                 C&L             CALAC
# 1                          SC05            CAL FIRE             CAFKU
# 2                          SC08                 C&L             CALAC
# 3                          SC12            CAL FIRE             CARRU
# 4                          SC12            CAL FIRE             CARRU
# ...                         ...                 ...               ...
# 3870                       SW13                USFS             NMCIF
# 3871                       SW13                USFS             NMCIF
# 3872                       RM02                  SF             WYWYS
# 3873                       SA50                 FWS             FLEHR
# 3874                       SA27                 DVF             KYKYS
#
#      POOState  PredominantFuelGroup PredominantFuelModel PrimaryFuelModel  \
# 0       US-CA                   NaN                  NaN              NaN
# 1       US-CA                   NaN                  NaN              NaN
# 2       US-CA                   NaN                  NaN              NaN
# 3       US-CA                   NaN                  NaN              NaN
# 4       US-CA                   NaN                  NaN              NaN
# ...       ...                   ...                  ...              ...
# 3870    US-NM                   NaN                  NaN              NaN
# 3871    US-NM                   NaN                  NaN              NaN
# 3872    US-WY                   NaN                  NaN              NaN
# 3873    US-FL                   NaN                  NaN              NaN
# 3874    US-KY                   NaN                  NaN              NaN
#
#      SecondaryFuelModel  TotalIncidentPersonnel   UniqueFireIdentifier  \
# 0                   NaN                     NaN      2023-CALAC-447492
# 1                   NaN                     NaN      2023-CAFKU-022959
# 2                   NaN                     NaN      2023-CALAC-000069
# 3                   NaN                     NaN      2023-CARRU-000014
# 4                   NaN                     NaN      2023-CARRU-000035
# ...                 ...                     ...                    ...
# 3870                NaN                     NaN      2023-NMCIF-000048
# 3871                NaN                     NaN      2023-NMCIF-000049
# 3872                NaN                     NaN  2023-WYWYS-0352100009
# 3873                NaN                     NaN      2023-FLEHR-001065
# 3874                NaN                     NaN   2023-KYKYS-231750330
#
#      WFDSSDecisionStatus  EstimatedFinalCost OrganizationalAssessment  \
# 0            No Decision                 NaN                      NaN
# 1            No Decision                 NaN                      NaN
# 2            No Decision                 NaN                      NaN
# 3            No Decision                 NaN                      NaN
# 4            No Decision                 NaN                      NaN
# ...                  ...                 ...                      ...
# 3870         No Decision                 NaN                      NaN
# 3871         No Decision                 NaN                      NaN
# 3872         No Decision                 NaN                      NaN
# 3873         No Decision                 NaN                      NaN
# 3874         No Decision                 NaN                      NaN
#
#      StrategicDecisionPublishDate    CreatedOnDateTime_dt  \
# 0                             NaN  2023/01/01 04:46:49+00
# 1                             NaN  2023/01/01 06:20:31+00
# 2                             NaN  2023/01/01 08:58:48+00
# 3                             NaN  2023/01/01 08:59:27+00
# 4                             NaN  2023/01/01 10:11:33+00
# ...                           ...                     ...
# 3870                          NaN  2023/03/22 13:34:51+00
# 3871                          NaN  2023/03/22 13:37:08+00
# 3872                          NaN  2023/03/22 13:54:00+00
# 3873                          NaN  2023/03/22 13:58:32+00
# 3874                          NaN  2023/03/22 14:02:48+00
#
#        ModifiedOnDateTime_dt  IsCpxChild  CpxName  CpxID  \
# 0     2023/01/01 04:46:49+00           0      NaN    NaN
# 1     2023/01/01 06:20:41+00           0      NaN    NaN
# 2     2023/01/01 08:58:48+00           0      NaN    NaN
# 3     2023/01/01 08:59:27+00           0      NaN    NaN
# 4     2023/01/01 10:11:33+00           0      NaN    NaN
# ...                      ...         ...      ...    ...
# 3870  2023/03/22 13:34:53+00           0      NaN    NaN
# 3871  2023/03/22 13:37:40+00           0      NaN    NaN
# 3872  2023/03/22 13:54:00+00           0      NaN    NaN
# 3873  2023/03/22 13:58:33+00           0      NaN    NaN
# 3874  2023/03/22 14:03:24+00           0      NaN    NaN
#
#                               SourceGlobalID  \
# 0     {46374510-C3AE-4B21-BF99-F6E8DCE39EA7}
# 1     {B7688735-6981-41E5-B06C-235A96FEABE3}
# 2     {8DC41F9E-8F7F-435B-BFA1-BBBD7B4DE521}
# 3     {5977CB1E-0C9B-4523-A3F1-DF1A9B7A04E5}
# 4     {D57703B0-60A2-4F8C-91F9-204E5282DB63}
# ...                                      ...
# 3870  {B8AF1D71-8CEF-4555-8104-9799683C16F4}
# 3871  {DA6F4F4F-111A-4BA2-A3A4-2CC8DF41CF5C}
# 3872  {008EDF6B-9FEF-4100-8ABA-5A84F43C737F}
# 3873  {EAE4613E-CDD6-46B8-B7CE-24BB3775D12F}
# 3874  {21A8B8BB-9DCE-441E-A097-2550F3A7500B}
#
#                                     GlobalID
# 0     {BB4A69D2-8CE1-4E2F-B8B4-C589EE47536B}
# 1     {D4CA8250-A331-4193-84E7-D022727792E1}
# 2     {92C597A7-B3E6-4F83-8309-FB25C6DA6A5B}
# 3     {011F9ED0-F42E-4D21-88DD-5BD442B20A58}
# 4     {FA343640-3900-49CE-B93F-F36D05650EA8}
# ...                                      ...
# 3870  {985373ED-100B-42EA-9603-EBB8BB31D11B}
# 3871  {7F1A68CE-6744-423D-9193-0895337FF80F}
# 3872  {7C2D57FA-F0EF-4F7B-BA5A-154BCC9D1C62}
# 3873  {11787992-C372-45AE-ADCC-F19B1F6CDFFE}
# 3874  {207DC50A-FF17-4F41-B425-8633E891C9C9}
#
# [3875 rows x 97 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3875 entries, 0 to 3874
# Data columns (total 97 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   X                                3875 non-null   float64
#  1   Y                                3875 non-null   float64
#  2   OBJECTID                         3875 non-null   int64
#  3   SourceOID                        3875 non-null   int64
#  4   ABCDMisc                         33 non-null     object
#  5   ADSPermissionState               3875 non-null   object
#  6   ContainmentDateTime              1491 non-null   object
#  7   ControlDateTime                  1062 non-null   object
#  8   CreatedBySystem                  3875 non-null   object
#  9   IncidentSize                     2936 non-null   float64
#  10  DiscoveryAcres                   3562 non-null   float64
#  11  DispatchCenterID                 3875 non-null   object
#  12  EstimatedCostToDate              128 non-null    float64
#  13  FinalAcres                       287 non-null    float64
#  14  FinalFireReportApprovedByTitle   0 non-null      float64
#  15  FinalFireReportApprovedByUnit    0 non-null      float64
#  16  FinalFireReportApprovedDate      0 non-null      float64
#  17  FireBehaviorGeneral              238 non-null    object
#  18  FireBehaviorGeneral1             2 non-null      object
#  19  FireBehaviorGeneral2             59 non-null     object
#  20  FireBehaviorGeneral3             28 non-null     object
#  21  FireCause                        3570 non-null   object
#  22  FireCauseGeneral                 215 non-null    object
#  23  FireCauseSpecific                112 non-null    object
#  24  FireCode                         919 non-null    object
#  25  FireDepartmentID                 16 non-null     object
#  26  FireDiscoveryDateTime            3875 non-null   object
#  27  FireMgmtComplexity               347 non-null    object
#  28  FireOutDateTime                  997 non-null    object
#  29  FireStrategyConfinePercent       128 non-null    float64
#  30  FireStrategyFullSuppPercent      128 non-null    float64
#  31  FireStrategyMonitorPercent       128 non-null    float64
#  32  FireStrategyPointZonePercent     128 non-null    float64
#  33  FSJobCode                        644 non-null    object
#  34  FSOverrideCode                   653 non-null    float64
#  35  GACC                             3875 non-null   object
#  36  ICS209ReportDateTime             128 non-null    object
#  37  ICS209ReportForTimePeriodFrom    128 non-null    object
#  38  ICS209ReportForTimePeriodTo      128 non-null    object
#  39  ICS209ReportStatus               128 non-null    object
#  40  IncidentManagementOrganization   128 non-null    object
#  41  IncidentName                     3875 non-null   object
#  42  IncidentShortDescription         128 non-null    object
#  43  IncidentTypeCategory             3875 non-null   object
#  44  IncidentTypeKind                 3875 non-null   object
#  45  InitialLatitude                  3442 non-null   float64
#  46  InitialLongitude                 3442 non-null   float64
#  47  InitialResponseAcres             1349 non-null   float64
#  48  InitialResponseDateTime          8 non-null      object
#  49  IrwinID                          3875 non-null   object
#  50  IsFireCauseInvestigated          8 non-null      float64
#  51  IsFireCodeRequested              3875 non-null   int64
#  52  IsFSAssisted                     2997 non-null   float64
#  53  IsMultiJurisdictional            2864 non-null   float64
#  54  IsReimbursable                   2865 non-null   float64
#  55  IsTrespass                       2871 non-null   float64
#  56  IsUnifiedCommand                 347 non-null    float64
#  57  LocalIncidentIdentifier          3875 non-null   object
#  58  ModifiedBySystem                 3875 non-null   object
#  59  PercentContained                 347 non-null    float64
#  60  PercentPerimeterToBeContained    128 non-null    float64
#  61  POOCity                          91 non-null     object
#  62  POOCounty                        3875 non-null   object
#  63  POODispatchCenterID              3875 non-null   object
#  64  POOFips                          3875 non-null   object
#  65  POOJurisdictionalAgency          2027 non-null   object
#  66  POOJurisdictionalUnit            1986 non-null   object
#  67  POOJurisdictionalUnitParentUnit  0 non-null      float64
#  68  POOLandownerCategory             3874 non-null   object
#  69  POOLandownerKind                 3874 non-null   object
#  70  POOLegalDescPrincipalMeridian    4 non-null      object
#  71  POOLegalDescQtr                  1 non-null      object
#  72  POOLegalDescQtrQtr               0 non-null      float64
#  73  POOLegalDescRange                4 non-null      object
#  74  POOLegalDescSection              4 non-null      float64
#  75  POOLegalDescTownship             4 non-null      object
#  76  POOPredictiveServiceAreaID       3875 non-null   object
#  77  POOProtectingAgency              3873 non-null   object
#  78  POOProtectingUnit                3875 non-null   object
#  79  POOState                         3875 non-null   object
#  80  PredominantFuelGroup             0 non-null      float64
#  81  PredominantFuelModel             55 non-null     object
#  82  PrimaryFuelModel                 272 non-null    object
#  83  SecondaryFuelModel               56 non-null     object
#  84  TotalIncidentPersonnel           115 non-null    float64
#  85  UniqueFireIdentifier             3875 non-null   object
#  86  WFDSSDecisionStatus              3875 non-null   object
#  87  EstimatedFinalCost               2 non-null      float64
#  88  OrganizationalAssessment         2 non-null      object
#  89  StrategicDecisionPublishDate     2 non-null      object
#  90  CreatedOnDateTime_dt             3875 non-null   object
#  91  ModifiedOnDateTime_dt            3875 non-null   object
#  92  IsCpxChild                       3875 non-null   int64
#  93  CpxName                          0 non-null      float64
#  94  CpxID                            0 non-null      float64
#  95  SourceGlobalID                   3875 non-null   object
#  96  GlobalID                         3875 non-null   object
# dtypes: float64(33), int64(4), object(60)
# memory usage: 2.9+ MB

# %%
df['POODispatchCenterID'].unique()
# Out:
# array(['CALACC', 'CASICC', 'CARRCC', 'CASDIC', 'TXTIC', 'CATGCC', 'NHNEC',
#        'CAOVCC', 'ARAOC', 'SDGPC', 'AZTDC', 'FLFIC', 'CODRC', 'NMTDC',
#        'CARICC', 'CASBCC', 'MTKDC', 'WACWC', 'ORLFC', 'CACICC', 'WANEC',
#        'TNTNC', 'MTLEC', 'ILILC', 'COMTC', 'MTBFAC', 'NMADC', 'CAYICC',
#        'INIIC', 'MSMIC', 'AZPDC', 'CASIFC', 'CAFICC', 'AZSDC', 'CAANCC',
#        'CASBDC', 'CAVNCC', 'CALPCC', 'WYCPC', 'KYKIC', 'AZFDC', 'COPBC',
#        'OREIC', 'LALIC', 'IDSCC', 'MNMNCC', 'NCNCC', 'MTGDC', 'CALNCC',
#        'MTHDC', 'MTDDC', 'MOMOC', 'MTBZC', 'NMSDC', 'WIWIC', 'GAGIC',
#        'SCSCC', 'NMABC', 'MTBDC', 'CABECC', 'COFTC', 'COCRC', 'CAPNFC',
#        'WAPSC', 'CAMECC', 'NDNDC', 'AKMSSC', 'AZPHC', 'CANCIC', 'PAMACC',
#        'IDBDC', 'ORCOC', 'UTCDC', 'CAORCC', 'ALAIC', 'CASTCC', 'CAMMCC',
#        'NVLIC', 'CAGVCC', 'NMSFC', 'CATCCC', 'CASQCC', 'MTFBAC', 'VAVIC',
#        'AZWDC', 'CACCCC', 'CACZCC', 'MTFHA', 'CASLCC', 'ORVAC', 'ORBIC',
#        'MIMIDC', 'FLSEAC', 'CAMICC', 'WACCC', 'CABTCC', 'NVSFC', 'CAMRNC',
#        'WACAC', 'PRCIC', 'CASCCC', 'IDGVC', 'IDCDC', 'UTNUC', 'MTRBAC',
#        'UTRFC', 'ORBMC', 'AZNAOC', 'IDEIC', 'WYCDC', 'MTMCC', 'AKCRSC',
#        'ORRICC', 'MTMDC', 'MTBRC', 'MTKIC', 'NVEIC', 'WAYAC'],
#       dtype=object)

# %%
df_caSelector=df['POODispatchCenterID'].str.startswith('CA')
df_ca=df[df_caSelector]
df_ca
# df=df[df['POODispatchCenterID'].str.contains('CA')]
# df
# Out:
#                X          Y  OBJECTID  SourceOID ABCDMisc ADSPermissionState  \
# 0    -118.106402  33.891095    292628   23872143      NaN            DEFAULT
# 1    -120.437306  36.821662    292630   23872145      NaN            DEFAULT
# 2    -117.890182  34.121065    292661   23872184      NaN            DEFAULT
# 3    -116.227787  33.719351    292664   23872185      NaN            DEFAULT
# 4    -116.509916  33.962375    292672   23872187      NaN            DEFAULT
# ...          ...        ...       ...        ...      ...                ...
# 3844 -120.600280  37.083098    300069   28020396      NaN            DEFAULT
# 3850 -116.129198  33.642083    300075   28020402      NaN            DEFAULT
# 3855 -117.244586  33.939066    300083   28020410      NaN            DEFAULT
# 3857 -118.076522  34.645925    300087   28020414      NaN            DEFAULT
# 3867 -117.259756  33.917298    300100   28020427      NaN            DEFAULT
#
#          ContainmentDateTime         ControlDateTime CreatedBySystem  \
# 0                        NaN                     NaN         lacocad
# 1     2023/01/01 06:20:56+00  2023/01/01 06:21:02+00           cfcad
# 2                        NaN                     NaN         lacocad
# 3                        NaN                     NaN           cfcad
# 4                        NaN                     NaN           cfcad
# ...                      ...                     ...             ...
# 3844  2023/03/22 00:35:54+00  2023/03/22 00:35:55+00           cfcad
# 3850                     NaN                     NaN           cfcad
# 3855                     NaN                     NaN           cfcad
# 3857                     NaN                     NaN         lacocad
# 3867                     NaN                     NaN           cfcad
#
#       IncidentSize  DiscoveryAcres DispatchCenterID  EstimatedCostToDate  \
# 0              NaN            0.01           CALACC                  NaN
# 1             0.01            0.01           CAFKCC                  NaN
# 2              NaN            0.01           CALACC                  NaN
# 3              NaN            0.01           CARRCC                  NaN
# 4              NaN            0.01           CARRCC                  NaN
# ...            ...             ...              ...                  ...
# 3844          0.50            0.01           CAMMCC                  NaN
# 3850           NaN            0.01           CARRCC                  NaN
# 3855           NaN            0.01           CARRCC                  NaN
# 3857           NaN            0.01           CALACC                  NaN
# 3867           NaN            0.01           CARRCC                  NaN
#
#       FinalAcres  FinalFireReportApprovedByTitle  \
# 0            NaN                             NaN
# 1            NaN                             NaN
# 2            NaN                             NaN
# 3            NaN                             NaN
# 4            NaN                             NaN
# ...          ...                             ...
# 3844         0.5                             NaN
# 3850         NaN                             NaN
# 3855         NaN                             NaN
# 3857         NaN                             NaN
# 3867         NaN                             NaN
#
#       FinalFireReportApprovedByUnit  FinalFireReportApprovedDate  \
# 0                               NaN                          NaN
# 1                               NaN                          NaN
# 2                               NaN                          NaN
# 3                               NaN                          NaN
# 4                               NaN                          NaN
# ...                             ...                          ...
# 3844                            NaN                          NaN
# 3850                            NaN                          NaN
# 3855                            NaN                          NaN
# 3857                            NaN                          NaN
# 3867                            NaN                          NaN
#
#      FireBehaviorGeneral FireBehaviorGeneral1 FireBehaviorGeneral2  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3                    NaN                  NaN                  NaN
# 4                    NaN                  NaN                  NaN
# ...                  ...                  ...                  ...
# 3844                 NaN                  NaN                  NaN
# 3850                 NaN                  NaN                  NaN
# 3855                 NaN                  NaN                  NaN
# 3857                 NaN                  NaN                  NaN
# 3867                 NaN                  NaN                  NaN
#
#      FireBehaviorGeneral3     FireCause FireCauseGeneral FireCauseSpecific  \
# 0                     NaN  Undetermined              NaN               NaN
# 1                     NaN  Undetermined              NaN               NaN
# 2                     NaN  Undetermined              NaN               NaN
# 3                     NaN  Undetermined              NaN               NaN
# 4                     NaN  Undetermined              NaN               NaN
# ...                   ...           ...              ...               ...
# 3844                  NaN  Undetermined              NaN               NaN
# 3850                  NaN  Undetermined              NaN               NaN
# 3855                  NaN  Undetermined              NaN               NaN
# 3857                  NaN  Undetermined              NaN               NaN
# 3867                  NaN  Undetermined              NaN               NaN
#
#      FireCode FireDepartmentID   FireDiscoveryDateTime FireMgmtComplexity  \
# 0         NaN              NaN  2023/01/01 04:43:57+00                NaN
# 1         NaN              NaN  2023/01/01 05:31:41+00                NaN
# 2         NaN              NaN  2023/01/01 08:55:36+00                NaN
# 3         NaN              NaN  2023/01/01 08:22:21+00                NaN
# 4         NaN              NaN  2023/01/01 08:48:45+00                NaN
# ...       ...              ...                     ...                ...
# 3844      NaN              NaN  2023/03/22 00:11:42+00                NaN
# 3850      NaN              NaN  2023/03/22 00:32:12+00                NaN
# 3855      NaN              NaN  2023/03/22 07:30:14+00                NaN
# 3857      NaN              NaN  2023/03/22 11:06:56+00                NaN
# 3867      NaN              NaN  2023/03/22 13:07:56+00                NaN
#
#      FireOutDateTime  FireStrategyConfinePercent  FireStrategyFullSuppPercent  \
# 0                NaN                         NaN                          NaN
# 1                NaN                         NaN                          NaN
# 2                NaN                         NaN                          NaN
# 3                NaN                         NaN                          NaN
# 4                NaN                         NaN                          NaN
# ...              ...                         ...                          ...
# 3844             NaN                         NaN                          NaN
# 3850             NaN                         NaN                          NaN
# 3855             NaN                         NaN                          NaN
# 3857             NaN                         NaN                          NaN
# 3867             NaN                         NaN                          NaN
#
#       FireStrategyMonitorPercent  FireStrategyPointZonePercent FSJobCode  \
# 0                            NaN                           NaN       NaN
# 1                            NaN                           NaN       NaN
# 2                            NaN                           NaN       NaN
# 3                            NaN                           NaN       NaN
# 4                            NaN                           NaN       NaN
# ...                          ...                           ...       ...
# 3844                         NaN                           NaN       NaN
# 3850                         NaN                           NaN       NaN
# 3855                         NaN                           NaN       NaN
# 3857                         NaN                           NaN       NaN
# 3867                         NaN                           NaN       NaN
#
#       FSOverrideCode  GACC ICS209ReportDateTime ICS209ReportForTimePeriodFrom  \
# 0                NaN  OSCC                  NaN                           NaN
# 1                NaN  OSCC                  NaN                           NaN
# 2                NaN  OSCC                  NaN                           NaN
# 3                NaN  OSCC                  NaN                           NaN
# 4                NaN  OSCC                  NaN                           NaN
# ...              ...   ...                  ...                           ...
# 3844             NaN  OSCC                  NaN                           NaN
# 3850             NaN  OSCC                  NaN                           NaN
# 3855             NaN  OSCC                  NaN                           NaN
# 3857             NaN  OSCC                  NaN                           NaN
# 3867             NaN  OSCC                  NaN                           NaN
#
#      ICS209ReportForTimePeriodTo ICS209ReportStatus  \
# 0                            NaN                NaN
# 1                            NaN                NaN
# 2                            NaN                NaN
# 3                            NaN                NaN
# 4                            NaN                NaN
# ...                          ...                ...
# 3844                         NaN                NaN
# 3850                         NaN                NaN
# 3855                         NaN                NaN
# 3857                         NaN                NaN
# 3867                         NaN                NaN
#
#      IncidentManagementOrganization              IncidentName  \
# 0                               NaN                LAC-447492
# 1                               NaN  W BULLARD AVE  FIREBAUGH
# 2                               NaN                LAC-000069
# 3                               NaN            BLISS AV  INDO
# 4                               NaN              1ST ST  DHSP
# ...                             ...                       ...
# 3844                            NaN  INDIANA AV / HUTCHINS RD
# 3850                            NaN  AIRPORT BL / FILLMORE ST
# 3855                            NaN        SUNNYMEAD BL  MOVA
# 3857                            NaN                LAC-097256
# 3867                            NaN       ALESSANDRO BL  MOVA
#
#      IncidentShortDescription IncidentTypeCategory IncidentTypeKind  \
# 0                         NaN                   WF               FI
# 1                         NaN                   RX               FI
# 2                         NaN                   WF               FI
# 3                         NaN                   WF               FI
# 4                         NaN                   WF               FI
# ...                       ...                  ...              ...
# 3844                      NaN                   WF               FI
# 3850                      NaN                   WF               FI
# 3855                      NaN                   WF               FI
# 3857                      NaN                   WF               FI
# 3867                      NaN                   WF               FI
#
#       InitialLatitude  InitialLongitude  InitialResponseAcres  \
# 0           33.891090       -118.106390                   NaN
# 1           36.821657       -120.437293                   NaN
# 2           34.121060       -117.890170                   NaN
# 3           33.719346       -116.227775                   NaN
# 4           33.962370       -116.509904                   NaN
# ...               ...               ...                   ...
# 3844        37.083093       -120.600267                   NaN
# 3850        33.642078       -116.129186                   NaN
# 3855        33.939061       -117.244574                   NaN
# 3857        34.645920       -118.076510                   NaN
# 3867        33.917293       -117.259744                   NaN
#
#      InitialResponseDateTime                                 IrwinID  \
# 0                        NaN  {CBF6F6BE-5A91-4963-B989-B53898DD0EEC}
# 1                        NaN  {8B3AE160-4F81-4A3D-850C-F931BADDD17C}
# 2                        NaN  {16443D72-F126-474A-B3B2-D21BFA7269CD}
# 3                        NaN  {D54F2E4C-AAE4-4EED-AEC9-63396F1FB6A4}
# 4                        NaN  {984EF428-A7DC-434C-A6DD-12345A31FEC1}
# ...                      ...                                     ...
# 3844                     NaN  {E8149DCD-62EB-4034-B345-A80B27EA9D0A}
# 3850                     NaN  {C0F06341-C9A1-4E5F-83E2-CA215109B698}
# 3855                     NaN  {A8215EC5-8F85-4FBD-8397-5519606CA3D7}
# 3857                     NaN  {6512F6AC-3D7B-46B4-9AEC-A90B8B50C3AD}
# 3867                     NaN  {BB6B6FF3-912D-48B2-9302-16FE9C24F3C9}
#
#       IsFireCauseInvestigated  IsFireCodeRequested  IsFSAssisted  \
# 0                         NaN                    0           NaN
# 1                         NaN                    0           0.0
# 2                         NaN                    0           NaN
# 3                         NaN                    0           0.0
# 4                         NaN                    0           0.0
# ...                       ...                  ...           ...
# 3844                      NaN                    0           0.0
# 3850                      NaN                    0           0.0
# 3855                      NaN                    0           0.0
# 3857                      NaN                    0           NaN
# 3867                      NaN                    0           0.0
#
#       IsMultiJurisdictional  IsReimbursable  IsTrespass  IsUnifiedCommand  \
# 0                       NaN             NaN         NaN               NaN
# 1                       0.0             0.0         0.0               NaN
# 2                       NaN             NaN         NaN               NaN
# 3                       0.0             0.0         0.0               NaN
# 4                       0.0             0.0         0.0               NaN
# ...                     ...             ...         ...               ...
# 3844                    0.0             0.0         0.0               NaN
# 3850                    0.0             0.0         0.0               NaN
# 3855                    0.0             0.0         0.0               NaN
# 3857                    NaN             NaN         NaN               NaN
# 3867                    0.0             0.0         0.0               NaN
#
#      LocalIncidentIdentifier ModifiedBySystem  PercentContained  \
# 0                     447492          lacocad               NaN
# 1                     022959            cfcad               NaN
# 2                     000069          lacocad               NaN
# 3                     000014            cfcad               NaN
# 4                     000035            cfcad               NaN
# ...                      ...              ...               ...
# 3844                  006193            cfcad               NaN
# 3850                  042145            cfcad               NaN
# 3855                  042318            cfcad               NaN
# 3857                  097256          lacocad               NaN
# 3867                  042369            cfcad               NaN
#
#       PercentPerimeterToBeContained POOCity    POOCounty POODispatchCenterID  \
# 0                               NaN     NaN  Los Angeles              CALACC
# 1                               NaN     NaN       Fresno              CASICC
# 2                               NaN     NaN  Los Angeles              CALACC
# 3                               NaN     NaN    Riverside              CARRCC
# 4                               NaN     NaN    Riverside              CARRCC
# ...                             ...     ...          ...                 ...
# 3844                            NaN     NaN       Merced              CAMMCC
# 3850                            NaN     NaN    Riverside              CARRCC
# 3855                            NaN     NaN    Riverside              CARRCC
# 3857                            NaN     NaN  Los Angeles              CALACC
# 3867                            NaN     NaN    Riverside              CARRCC
#
#      POOFips POOJurisdictionalAgency POOJurisdictionalUnit  \
# 0      06037                     NaN                   NaN
# 1      06019                     NaN                   NaN
# 2      06037                     NaN                   NaN
# 3      06065                     NaN                   NaN
# 4      06065                     NaN                   NaN
# ...      ...                     ...                   ...
# 3844   06047                     NaN                   NaN
# 3850   06065                     NaN                   NaN
# 3855   06065                     NaN                   NaN
# 3857   06037                     NaN                   NaN
# 3867   06065                     NaN                   NaN
#
#       POOJurisdictionalUnitParentUnit POOLandownerCategory POOLandownerKind  \
# 0                                 NaN              Private          Private
# 1                                 NaN              Private          Private
# 2                                 NaN              Private          Private
# 3                                 NaN              Private          Private
# 4                                 NaN              Private          Private
# ...                               ...                  ...              ...
# 3844                              NaN              Private          Private
# 3850                              NaN              Private          Private
# 3855                              NaN              Private          Private
# 3857                              NaN              Private          Private
# 3867                              NaN              Private          Private
#
#      POOLegalDescPrincipalMeridian POOLegalDescQtr  POOLegalDescQtrQtr  \
# 0                              NaN             NaN                 NaN
# 1                              NaN             NaN                 NaN
# 2                              NaN             NaN                 NaN
# 3                              NaN             NaN                 NaN
# 4                              NaN             NaN                 NaN
# ...                            ...             ...                 ...
# 3844                           NaN             NaN                 NaN
# 3850                           NaN             NaN                 NaN
# 3855                           NaN             NaN                 NaN
# 3857                           NaN             NaN                 NaN
# 3867                           NaN             NaN                 NaN
#
#      POOLegalDescRange  POOLegalDescSection POOLegalDescTownship  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
# ...                ...                  ...                  ...
# 3844               NaN                  NaN                  NaN
# 3850               NaN                  NaN                  NaN
# 3855               NaN                  NaN                  NaN
# 3857               NaN                  NaN                  NaN
# 3867               NaN                  NaN                  NaN
#
#      POOPredictiveServiceAreaID POOProtectingAgency POOProtectingUnit  \
# 0                          SC08                 C&L             CALAC
# 1                          SC05            CAL FIRE             CAFKU
# 2                          SC08                 C&L             CALAC
# 3                          SC12            CAL FIRE             CARRU
# 4                          SC12            CAL FIRE             CARRU
# ...                         ...                 ...               ...
# 3844                       SC05            CAL FIRE             CAMMU
# 3850                       SC12            CAL FIRE             CARRU
# 3855                       SC08            CAL FIRE             CARRU
# 3857                       SC15                 C&L             CALAC
# 3867                       SC08            CAL FIRE             CARRU
#
#      POOState  PredominantFuelGroup PredominantFuelModel PrimaryFuelModel  \
# 0       US-CA                   NaN                  NaN              NaN
# 1       US-CA                   NaN                  NaN              NaN
# 2       US-CA                   NaN                  NaN              NaN
# 3       US-CA                   NaN                  NaN              NaN
# 4       US-CA                   NaN                  NaN              NaN
# ...       ...                   ...                  ...              ...
# 3844    US-CA                   NaN                  NaN              NaN
# 3850    US-CA                   NaN                  NaN              NaN
# 3855    US-CA                   NaN                  NaN              NaN
# 3857    US-CA                   NaN                  NaN              NaN
# 3867    US-CA                   NaN                  NaN              NaN
#
#      SecondaryFuelModel  TotalIncidentPersonnel UniqueFireIdentifier  \
# 0                   NaN                     NaN    2023-CALAC-447492
# 1                   NaN                     NaN    2023-CAFKU-022959
# 2                   NaN                     NaN    2023-CALAC-000069
# 3                   NaN                     NaN    2023-CARRU-000014
# 4                   NaN                     NaN    2023-CARRU-000035
# ...                 ...                     ...                  ...
# 3844                NaN                     NaN    2023-CAMMU-006193
# 3850                NaN                     NaN    2023-CARRU-042145
# 3855                NaN                     NaN    2023-CARRU-042318
# 3857                NaN                     NaN    2023-CALAC-097256
# 3867                NaN                     NaN    2023-CARRU-042369
#
#      WFDSSDecisionStatus  EstimatedFinalCost OrganizationalAssessment  \
# 0            No Decision                 NaN                      NaN
# 1            No Decision                 NaN                      NaN
# 2            No Decision                 NaN                      NaN
# 3            No Decision                 NaN                      NaN
# 4            No Decision                 NaN                      NaN
# ...                  ...                 ...                      ...
# 3844         No Decision                 NaN                      NaN
# 3850         No Decision                 NaN                      NaN
# 3855         No Decision                 NaN                      NaN
# 3857         No Decision                 NaN                      NaN
# 3867         No Decision                 NaN                      NaN
#
#      StrategicDecisionPublishDate    CreatedOnDateTime_dt  \
# 0                             NaN  2023/01/01 04:46:49+00
# 1                             NaN  2023/01/01 06:20:31+00
# 2                             NaN  2023/01/01 08:58:48+00
# 3                             NaN  2023/01/01 08:59:27+00
# 4                             NaN  2023/01/01 10:11:33+00
# ...                           ...                     ...
# 3844                          NaN  2023/03/22 00:36:00+00
# 3850                          NaN  2023/03/22 01:10:10+00
# 3855                          NaN  2023/03/22 07:36:23+00
# 3857                          NaN  2023/03/22 11:12:49+00
# 3867                          NaN  2023/03/22 13:25:33+00
#
#        ModifiedOnDateTime_dt  IsCpxChild  CpxName  CpxID  \
# 0     2023/01/01 04:46:49+00           0      NaN    NaN
# 1     2023/01/01 06:20:41+00           0      NaN    NaN
# 2     2023/01/01 08:58:48+00           0      NaN    NaN
# 3     2023/01/01 08:59:27+00           0      NaN    NaN
# 4     2023/01/01 10:11:33+00           0      NaN    NaN
# ...                      ...         ...      ...    ...
# 3844  2023/03/22 00:36:15+00           0      NaN    NaN
# 3850  2023/03/22 01:10:10+00           0      NaN    NaN
# 3855  2023/03/22 07:36:23+00           0      NaN    NaN
# 3857  2023/03/22 11:12:49+00           0      NaN    NaN
# 3867  2023/03/22 13:25:33+00           0      NaN    NaN
#
#                               SourceGlobalID  \
# 0     {46374510-C3AE-4B21-BF99-F6E8DCE39EA7}
# 1     {B7688735-6981-41E5-B06C-235A96FEABE3}
# 2     {8DC41F9E-8F7F-435B-BFA1-BBBD7B4DE521}
# 3     {5977CB1E-0C9B-4523-A3F1-DF1A9B7A04E5}
# 4     {D57703B0-60A2-4F8C-91F9-204E5282DB63}
# ...                                      ...
# 3844  {BC93F727-BA6A-488E-A34A-61E46C1E94F5}
# 3850  {0062FE09-4AB3-48E8-BB10-EB2C95810476}
# 3855  {34CEA345-9C43-437E-89BD-026B26B66CCE}
# 3857  {DF1CB7D0-F67C-4B6B-91D9-AD3B46CDDF15}
# 3867  {1EBCCB95-BBAB-4573-A4E1-AD5661E80A63}
#
#                                     GlobalID
# 0     {BB4A69D2-8CE1-4E2F-B8B4-C589EE47536B}
# 1     {D4CA8250-A331-4193-84E7-D022727792E1}
# 2     {92C597A7-B3E6-4F83-8309-FB25C6DA6A5B}
# 3     {011F9ED0-F42E-4D21-88DD-5BD442B20A58}
# 4     {FA343640-3900-49CE-B93F-F36D05650EA8}
# ...                                      ...
# 3844  {6B38E9D9-5D94-4ED1-88F6-FBA2CB1981A2}
# 3850  {4ABC3F1C-772D-43D8-B7E4-C1762C1ED685}
# 3855  {480FF0DF-BFF0-40B3-A722-0BB4373E765E}
# 3857  {44DC9A92-42A1-4383-ACA5-BEA92C903CF2}
# 3867  {ACFD3D79-E08D-4C3F-8BD9-220104D020D2}
#
# [1153 rows x 97 columns]

# %%
df_ca.count()
# Out:
# X                 1153
# Y                 1153
# OBJECTID          1153
# SourceOID         1153
# ABCDMisc             0
#                   ...
# IsCpxChild        1153
# CpxName              0
# CpxID                0
# SourceGlobalID    1153
# GlobalID          1153
# Length: 97, dtype: int64

# %%
df_ca['FinalAcres'].describe()
# Out:
# count    203.000000
# mean       0.119951
# std        0.460305
# min        0.010000
# 25%        0.010000
# 50%        0.010000
# 75%        0.010000
# max        3.700000
# Name: FinalAcres, dtype: float64

# %%
df_ca['IncidentSize'].describe()
# Out:
# count    376.000000
# mean       1.383617
# std       15.201597
# min        0.010000
# 25%        0.010000
# 50%        0.010000
# 75%        0.132500
# max      250.000000
# Name: IncidentSize, dtype: float64

# %%
cwd = os.getcwd()
print('Current working directory\n',cwd)
